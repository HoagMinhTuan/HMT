# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

folder= '/content/drive/MyDrive/Colab Notebooks/TraiCay/'
for i in range(9):
  plt.subplot(330+i+1)
  filename = folder+'qua.'+str(i)+'.jpg'
  image = imread(filename)
  plt.imshow(image)
plt.show()

# %%
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img, img_to_array

folder= '/content/drive/MyDrive/Colab Notebooks/TraiCay/'

photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('qua.0'):
    output = 0
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('qua.1'):
    output = 1
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('qua.2'):
    output = 2
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('qua.3'):
    output = 3
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('qua.4'):
    output = 4
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('qua.5'):
    output = 5
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('qua.6'):
    output = 6
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('qua.7'):
    output = 7
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('qua.8'):
    output = 8
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('qua.9'):
    output = 9
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
photos = asarray(photos)
labels = asarray(labels)
print(photos.shape,labels.shape)

save('10TraiCay_photos.npy', photos)
save('10TraiCay_labels.npy', labels)
# Out:
# (10, 200, 200, 3) (10,)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten # BatchNormalization: để dùng GPU ko lỗi
from tensorflow.keras.optimizers import SGD

model = Sequential([
    Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(200, 200, 3)),
    MaxPooling2D((2, 2)),
    
    Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    
    Flatten(),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
 history = model.fit(photos, labels, epochs=20, verbose=1)
# Out:
# Epoch 1/20
# 1/1 [==============================] - 1s 579ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 2/20
# 1/1 [==============================] - 1s 589ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 3/20
# 1/1 [==============================] - 1s 583ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 4/20
# 1/1 [==============================] - 1s 600ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 5/20
# 1/1 [==============================] - 1s 583ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 6/20
# 1/1 [==============================] - 1s 588ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 7/20
# 1/1 [==============================] - 1s 618ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 8/20
# 1/1 [==============================] - 1s 579ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 9/20
# 1/1 [==============================] - 1s 586ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 10/20
# 1/1 [==============================] - 1s 589ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 11/20
# 1/1 [==============================] - 1s 582ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 12/20
# 1/1 [==============================] - 1s 585ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 13/20
# 1/1 [==============================] - 1s 579ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 14/20
# 1/1 [==============================] - 1s 591ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 15/20
# 1/1 [==============================] - 1s 578ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 16/20
# 1/1 [==============================] - 1s 587ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 17/20
# 1/1 [==============================] - 1s 588ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 18/20
# 1/1 [==============================] - 1s 589ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 19/20
# 1/1 [==============================] - 1s 592ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 20/20
# 1/1 [==============================] - 1s 582ms/step - loss: 0.0000e+00 - accuracy: 1.0000

# %%
model.evaluate(photos,labels)
# Out:
# 1/1 [==============================] - 0s 166ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# [0.0, 1.0]

# %%
model.save('TraiCay.h5')

# %%
classes = ["xoai","dautay","na","dua","luu","oi","duahau","dualuoi","saurieng","mangcut"]

# %%
from keras.models import load_model
models=load_model('TraiCay.h5')

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array

img = load_img('quaLuu.jpg', target_size=(200,200))
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array

img = load_img('quaNa.jpg', target_size=(200,200))
plt.imshow(img)

# %%
import numpy as np
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.00787392 0.01642651 0.05291018 0.0160255  0.7758205  0.03005244
#   0.01794705 0.00820643 0.05423436 0.02050317]]
# 'luu'
